# %% [markdown]
# This File was Used to to get the plots of the 3 models that Jon did

# %%
# from google.colab import drive
# drive.mount('/content/drive') #mounts google colab to my drive. Can be commented out when running locally

# %cd /content/drive/MyDrive/"Colab Notebooks"/"us-patent-phrase-to-phrase-matching"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/us-patent-phrase-to-phrase-matching

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %%
context_concat = keras.models.load_model("context_concat_model.h5")
base_model = keras.models.load_model("base_model.h5")
cbow = keras.models.load_model("cbow_model.h5")

# %%
keras.utils.plot_model(context_concat, to_file="Context_Concat_Model_Graph.png")

# %%
keras.utils.plot_model(base_model, to_file="Base_Model_Graph.png")

# %%
keras.utils.plot_model(cbow, to_file="CBOW_Model_Graph.png")
